# %% [markdown]
# # Setup for Amazon Bedrock
# * Container: `conda_python3` <BR>
# * We recommend `python 3.10` or later.
#     - version check: !python -V

# %% [markdown]
# ## 0. Materials
# - Bedrock user guide
#     - https://docs.aws.amazon.com/bedrock/latest/userguide/what-is-service.html
# - Step by step vidio tutorial
#     - https://www.youtube.com/watch?v=ab1mbj0acDo

# %% [markdown]
# ## 1. 설치 내용은 아래를 참조 해주세요.

# %% [markdown]
# [Setup for Amazon Bedrock](https://github.com/aws-samples/aws-ai-ml-workshop-kr/blob/master/genai/aws-gen-ai-kr/20_applications/09_genai_analytics/setup.ipynb)

# %% [markdown]
# ## 2. Install python SDK for bedrock

# %%
install_needed = True

# %%
import os
import sys
import IPython

if install_needed:
    print("installing deps and restarting kernel")
    # !{sys.executable} -m pip install -U pip
    # !{sys.executable} -m pip install -U awscli
    # !{sys.executable} -m pip install -U botocore
    # !{sys.executable} -m pip install -U boto3
    # !{sys.executable} -m pip install -U sagemaker 
    # !{sys.executable} -m pip install -U langchain
    # !{sys.executable} -m pip install -U langgraph
    # !{sys.executable} -m pip install -U termcolor
    # !{sys.executable} -m pip install -U langchain_anthropic
    
    # IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# installing deps and restarting kernel
# Requirement already satisfied: pip in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (24.2)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 71.9 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# Successfully installed pip-25.0.1
# Collecting awscli
#   Downloading awscli-1.38.9-py3-none-any.whl.metadata (11 kB)
# Collecting botocore==1.37.9 (from awscli)
#   Downloading botocore-1.37.9-py3-none-any.whl.metadata (5.7 kB)
# Collecting docutils<0.17,>=0.10 (from awscli)
#   Using cached docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from awscli)
#   Downloading s3transfer-0.11.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting PyYAML<6.1,>=3.10 (from awscli)
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting colorama<0.4.7,>=0.2.5 (from awscli)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli)
#   Using cached rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore==1.37.9->awscli)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from botocore==1.37.9->awscli) (2.9.0.post0)
# Collecting urllib3!=2.2.0,<3,>=1.25.4 (from botocore==1.37.9->awscli)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<4.8,>=3.1.2->awscli)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.37.9->awscli) (1.17.0)
# Downloading awscli-1.38.9-py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 62.2 MB/s eta 0:00:00
# Downloading botocore-1.37.9-py3-none-any.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 131.0 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached docutils-0.16-py2.py3-none-any.whl (548 kB)
# Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
# Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Downloading s3transfer-0.11.4-py3-none-any.whl (84 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, PyYAML, pyasn1, jmespath, docutils, colorama, rsa, botocore, s3transfer, awscli
# Successfully installed PyYAML-6.0.2 awscli-1.38.9 botocore-1.37.9 colorama-0.4.6 docutils-0.16 jmespath-1.0.1 pyasn1-0.6.1 rsa-4.7.2 s3transfer-0.11.4 urllib3-2.3.0
# Requirement already satisfied: botocore in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (1.37.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from botocore) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from botocore) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from botocore) (2.3.0)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.17.0)
# Collecting boto3
#   Downloading boto3-1.37.9-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: botocore<1.38.0,>=1.37.9 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from boto3) (1.37.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from boto3) (0.11.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from botocore<1.38.0,>=1.37.9->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from botocore<1.38.0,>=1.37.9->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.9->boto3) (1.17.0)
# Downloading boto3-1.37.9-py3-none-any.whl (139 kB)
# Installing collected packages: boto3
# Successfully installed boto3-1.37.9
# Collecting sagemaker
#   Downloading sagemaker-2.241.0-py3-none-any.whl.metadata (16 kB)
# Collecting attrs<24,>=23.1.0 (from sagemaker)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: boto3<2.0,>=1.35.75 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from sagemaker) (1.37.9)
# Collecting cloudpickle>=2.2.1 (from sagemaker)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting docker (from sagemaker)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting fastapi (from sagemaker)
#   Downloading fastapi-0.115.11-py3-none-any.whl.metadata (27 kB)
# Collecting google-pasta (from sagemaker)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting importlib-metadata<7.0,>=1.4.0 (from sagemaker)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting jsonschema (from sagemaker)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting numpy<2.0,>=1.9.0 (from sagemaker)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting omegaconf<=2.3,>=2.2 (from sagemaker)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging>=20.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from sagemaker) (24.2)
# Collecting pandas (from sagemaker)
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting pathos (from sagemaker)
#   Downloading pathos-0.3.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from sagemaker) (4.3.6)
# Collecting protobuf<6.0,>=3.12 (from sagemaker)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: psutil in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from sagemaker) (7.0.0)
# Requirement already satisfied: pyyaml~=6.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from sagemaker) (6.0.2)
# Collecting requests (from sagemaker)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting sagemaker-core<2.0.0,>=1.0.17 (from sagemaker)
#   Downloading sagemaker_core-1.0.25-py3-none-any.whl.metadata (4.9 kB)
# Collecting schema (from sagemaker)
#   Downloading schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Collecting smdebug-rulesconfig==1.0.1 (from sagemaker)
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl.metadata (943 bytes)
# Collecting tblib<4,>=1.7.0 (from sagemaker)
#   Downloading tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Collecting tqdm (from sagemaker)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from sagemaker) (2.3.0)
# Collecting uvicorn (from sagemaker)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: botocore<1.38.0,>=1.37.9 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from boto3<2.0,>=1.35.75->sagemaker) (1.37.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from boto3<2.0,>=1.35.75->sagemaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from boto3<2.0,>=1.35.75->sagemaker) (0.11.4)
# Requirement already satisfied: zipp>=0.5 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.21.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<=2.3,>=2.2->sagemaker)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pydantic<3.0.0,>=2.0.0 (from sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting rich<14.0.0,>=13.0.0 (from sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting mock<5.0,>4.0 (from sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Downloading mock-4.0.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->sagemaker)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema->sagemaker)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->sagemaker)
#   Downloading rpds_py-0.23.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests->sagemaker)
#   Downloading charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->sagemaker)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests->sagemaker)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi->sagemaker)
#   Downloading starlette-0.46.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from fastapi->sagemaker) (4.12.2)
# Requirement already satisfied: six in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from google-pasta->sagemaker) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from pandas->sagemaker) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->sagemaker)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->sagemaker)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting ppft>=1.7.6.9 (from pathos->sagemaker)
#   Downloading ppft-1.7.6.9-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3.9 (from pathos->sagemaker)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.5 (from pathos->sagemaker)
#   Downloading pox-0.3.5-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.17 (from pathos->sagemaker)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Collecting click>=7.0 (from uvicorn->sagemaker)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting h11>=0.8 (from uvicorn->sagemaker)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Downloading pydantic_core-2.27.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker) (2.19.1)
# Collecting anyio<5,>=3.6.2 (from starlette<0.47.0,>=0.40.0->fastapi->sagemaker)
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->sagemaker) (1.2.2)
# Collecting sniffio>=1.1 (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->sagemaker)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading sagemaker-2.241.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.5 MB/s eta 0:00:00
# Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 147.5 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading sagemaker_core-1.0.25-py3-none-any.whl (406 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading fastapi-0.115.11-py3-none-any.whl (94 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 160.2 MB/s eta 0:00:00
# Downloading pathos-0.3.3-py3-none-any.whl (82 kB)
# Downloading schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (146 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Downloading multiprocess-0.70.17-py310-none-any.whl (134 kB)
# Downloading pox-0.3.5-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.9-py3-none-any.whl (56 kB)
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 76.1 MB/s eta 0:00:00
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading rpds_py-0.23.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (386 kB)
# Downloading starlette-0.46.0-py3-none-any.whl (71 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=0536855277e5fd36c3973557724cf29a4be9930d877a22fb2e6c95864c0ed0e8
#   Stored in directory: /home/sagemaker-user/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# Installing collected packages: schema, pytz, antlr4-python3-runtime, tzdata, tqdm, tblib, sniffio, smdebug-rulesconfig, rpds-py, pydantic-core, protobuf, ppft, pox, omegaconf, numpy, mock, mdurl, importlib-metadata, idna, h11, google-pasta, dill, cloudpickle, click, charset-normalizer, certifi, attrs, annotated-types, uvicorn, requests, referencing, pydantic, pandas, multiprocess, markdown-it-py, anyio, starlette, rich, pathos, jsonschema-specifications, docker, jsonschema, fastapi, sagemaker-core, sagemaker
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.6.1
#     Uninstalling importlib_metadata-8.6.1:
#       Successfully uninstalled importlib_metadata-8.6.1
# Successfully installed annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 anyio-4.8.0 attrs-23.2.0 certifi-2025.1.31 charset-normalizer-3.4.1 click-8.1.8 cloudpickle-3.1.1 dill-0.3.9 docker-7.1.0 fastapi-0.115.11 google-pasta-0.2.0 h11-0.14.0 idna-3.10 importlib-metadata-6.11.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 markdown-it-py-3.0.0 mdurl-0.1.2 mock-4.0.3 multiprocess-0.70.17 numpy-1.26.4 omegaconf-2.3.0 pandas-2.2.3 pathos-0.3.3 pox-0.3.5 ppft-1.7.6.9 protobuf-5.29.3 pydantic-2.10.6 pydantic-core-2.27.2 pytz-2025.1 referencing-0.36.2 requests-2.32.3 rich-13.9.4 rpds-py-0.23.1 sagemaker-2.241.0 sagemaker-core-1.0.25 schema-0.7.7 smdebug-rulesconfig-1.0.1 sniffio-1.3.1 starlette-0.46.0 tblib-3.0.0 tqdm-4.67.1 tzdata-2025.1 uvicorn-0.34.0
# Collecting langchain
#   Downloading langchain-0.3.20-py3-none-any.whl.metadata (7.7 kB)
# Collecting langchain-core<1.0.0,>=0.3.41 (from langchain)
#   Downloading langchain_core-0.3.43-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.6 (from langchain)
#   Downloading langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.13-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain) (2.10.6)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.38-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: requests<3,>=2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain) (6.0.2)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.41->langchain)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.41->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading orjson-3.10.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.4,>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: anyio in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Downloading langchain-0.3.20-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.5 MB/s eta 0:00:00
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_core-0.3.43-py3-none-any.whl (415 kB)
# Downloading langchain_text_splitters-0.3.6-py3-none-any.whl (31 kB)
# Downloading langsmith-0.3.13-py3-none-any.whl (339 kB)
# Downloading SQLAlchemy-2.0.38-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 68.9 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.5/599.5 kB 30.8 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.10.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 130.0 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: zstandard, tenacity, orjson, jsonpointer, httpcore, greenlet, async-timeout, SQLAlchemy, requests-toolbelt, jsonpatch, httpx, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed SQLAlchemy-2.0.38 async-timeout-4.0.3 greenlet-3.1.1 httpcore-1.0.7 httpx-0.28.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.20 langchain-core-0.3.43 langchain-text-splitters-0.3.6 langsmith-0.3.13 orjson-3.10.15 requests-toolbelt-1.0.0 tenacity-9.0.0 zstandard-0.23.0
# Collecting langgraph
#   Downloading langgraph-0.3.5-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langgraph) (0.3.43)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.10 (from langgraph)
#   Downloading langgraph_checkpoint-2.0.18-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-prebuilt<0.2,>=0.1.1 (from langgraph)
#   Downloading langgraph_prebuilt-0.1.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.42 (from langgraph)
#   Downloading langgraph_sdk-0.1.55-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.1->langgraph) (0.3.13)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.1->langgraph) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.1->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.1->langgraph) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.1->langgraph) (2.10.6)
# Collecting msgpack<2.0.0,>=1.1.0 (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph)
#   Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: httpx>=0.25.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10.15)
# Requirement already satisfied: anyio in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (4.8.0)
# Requirement already satisfied: certifi in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.7)
# Requirement already satisfied: idna in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.1->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.1->langgraph) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.3.1)
# Downloading langgraph-0.3.5-py3-none-any.whl (131 kB)
# Downloading langgraph_checkpoint-2.0.18-py3-none-any.whl (39 kB)
# Downloading langgraph_prebuilt-0.1.2-py3-none-any.whl (24 kB)
# Downloading langgraph_sdk-0.1.55-py3-none-any.whl (45 kB)
# Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (378 kB)
# Installing collected packages: msgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph
# Successfully installed langgraph-0.3.5 langgraph-checkpoint-2.0.18 langgraph-prebuilt-0.1.2 langgraph-sdk-0.1.55 msgpack-1.1.0
# Collecting termcolor
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Installing collected packages: termcolor
# Successfully installed termcolor-2.5.0
# Collecting langchain_anthropic
#   Downloading langchain_anthropic-0.3.9-py3-none-any.whl.metadata (1.9 kB)
# Collecting anthropic<1,>=0.47.0 (from langchain_anthropic)
#   Using cached anthropic-0.49.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain_anthropic) (0.3.43)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain_anthropic) (2.10.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anthropic<1,>=0.47.0->langchain_anthropic) (4.8.0)
# Collecting distro<2,>=1.7.0 (from anthropic<1,>=0.47.0->langchain_anthropic)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anthropic<1,>=0.47.0->langchain_anthropic) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from anthropic<1,>=0.47.0->langchain_anthropic)
#   Downloading jiter-0.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anthropic<1,>=0.47.0->langchain_anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anthropic<1,>=0.47.0->langchain_anthropic) (4.12.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (0.3.13)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain_anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain_anthropic) (2.27.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.47.0->langchain_anthropic) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.47.0->langchain_anthropic) (3.10)
# Requirement already satisfied: certifi in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.47.0->langchain_anthropic) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.47.0->langchain_anthropic) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic<1,>=0.47.0->langchain_anthropic) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sagemaker-user/Self-Study-Generative-AI/.conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.41->langchain_anthropic) (2.3.0)
# Downloading langchain_anthropic-0.3.9-py3-none-any.whl (24 kB)
# Using cached anthropic-0.49.0-py3-none-any.whl (243 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Installing collected packages: jiter, distro, anthropic, langchain_anthropic
# Successfully installed anthropic-0.49.0 distro-1.9.0 jiter-0.8.2 langchain_anthropic-0.3.9
